# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhambudde1/collab/blob/main/stock_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import yfinance as yf

# For time stamps
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# used to add drive in the collab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # import `files` from the drive

# %%
import pandas as pd
file_path = '/content/drive/MyDrive/Coding/data/nse_stocks.csv'
df = pd.read_csv(file_path)

df.head()

# %%
display(df.head(10))

# %%
# The tech stocks we'll use for this analysis
tech_list_raw = df['SYMBOL'].head(10).tolist()
tech_list = [stock + '.NS' for stock in tech_list_raw]

# Set up End and Start times for data grab
end = datetime.now()
start = datetime(end.year - 1, end.month, end.day)

#For loop for grabing yahoo finance data and setting as a dataframe
for stock in tech_list:
    # Set DataFrame as the Stock Ticker
    globals()[stock.replace('.NS', '')] = yf.download(stock, start=start, end=end)

# %% [markdown]
# # for nifty ***50***

# %%
import pandas as pd
file_path50 = '/content/drive/MyDrive/Coding/data/historical_prices_50.csv'
df50 = pd.read_csv(file_path50)

df50.head()

# %%
display(df50.head())

# %%
df50['Year'].nunique()
# Out:
# 6

# %%
df50['Year'].unique()
# Out:
# array([2020, 2021, 2022, 2023, 2024, 2025], dtype=int32)

# %% [markdown]
# one `condition`

# %%
df50['growth_pct'] = ((df50[5] - df50[2]) / df50[2]) * 100
df_20_growth = df50[(df50['Year'] == 2020) & (df50['growth_pct'] < -20)]
# df_20_growth

# %% [markdown]
# two **condition**

# %%
df50['growth_pct'] = ((df50[5] - df50[2]) / df50[2]) * 100
df_20_growth = df50[(df50['Year'] == 2020) & (df50['growth_pct'] > -20) & (df50['growth_pct'] < -10)]

# %% [markdown]
# regroping ***creating*** two column from many and  adding names to column
#
# > Add blockquote

# %%
df_result = df_20_growth.copy()

# Round percentage (no decimals)
df_result['growth_pct'] = df_result['growth_pct'].round(0).astype(int)

# Keep only Symbol and Percentage columns
df_result = df_result[[0, 'growth_pct']]

# Rename columns (optional)
df_result.columns = ['Symbol', 'Growth%']

df_result
# Out:
#            Symbol  Growth%
# 28323  INDUSINDBK      -27
